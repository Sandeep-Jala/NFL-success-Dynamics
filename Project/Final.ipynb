# %% [markdown]
# # Beyond the Playbook: Unveiling the Hidden Dynamics of NFL Success through Climate, Betting, Crime, and Quarterback Insights
#
#
# ## Team Members:
# - Ishan Saksena (saksena)
# - Sandeep Jala (jsandeep)
# - Konstantinos Sarinopoulos (ksarinop)
#
# ## Overview
#
# Our project studies the correlation across a range of datasets: NFL statistics, weather, betting odds, quarterback performance, and crime data, with an end goal to develop a machine learning model for predicting NFL game outcomes. By analyzing these diverse data sets, the project aims to uncover hidden factors affecting team performance and offer a comprehensive prediction model that goes beyond traditional analytics, providing insights into the multifaceted influences on NFL games. We also aim to study correlations between the data, such as crime with betting, quarterback performance and the weather.
#
# ## Motivation
#
# The three of us are sports fans with an interest in true crime, and we were looking for ways to combine these interests. We chose this project because we're interested in finding out how different factors, like weather, betting odds, quarterback performance, and crime rates, can affect NFL games beyond just the usual stats. We believe by looking at these various elements together, we can uncover new insights and improve predictions on game outcomes, offering a fresh perspective to fans, bettors, and teams.
#
# ## Questions
#
#   - How do weather conditions affect the performance of home and away teams, especially in terms of scoring?:
#
#   Determine if weather factors like temperature, wind, and precipitation disproportionately affect the home or away teams, possibly due to familiarity with local conditions or weather-specific preparation.
#
#   - Does the crime rate in a team's state correlate with the team's performance, particularly home game outcomes?:
#
#   Investigate if higher crime rates in a team's state are associated with things like poorer home game performance. It can suggest things like external societal pressures or distractions could influence player focus or team cohesion. It could also see patterns between violent crime and the NFL’s violence.
#
#   - How do betting odds correlate with actual team performance and game outcomes in the NFL?:
#
#   By examining the relationship between the fluctuations in betting odds and the subsequent performance of teams in games, we aim to uncover patterns that might indicate how accurately the betting market anticipates real game outcomes.
#
#   - How does the presence of high-profile quarterbacks influence betting odds and public perception, regardless of the team's overall performance?:
#
#   Determine the effect of star quarterbacks on betting odds and public perception, revealing whether the presence of marquee players skews betting markets beyond what statistics alone would justify.
#
# ### Other Questions:
#
#   - Is there a correlation between local socioeconomic factors (reflected indirectly by crime data) and the betting market's expectations for a team's performance?:
#
#   Analyze how socioeconomic indicators, inferred from crime rates, correlate with betting odds to see if external factors influence public and market perceptions of team prospects.
#
#   - Can quarterback performance metrics predict the outcome of a game more accurately than betting odds?:
#
#   Assess the predictive accuracy of detailed quarterback metrics compared to betting odds, aiming to identify if nuanced player performance insights offer a better prediction model than the general betting consensus.
#
#   - How does the betting market react to weather conditions on game day?:
#
#   Analyze how weather data is correlated with the betting market and winning conditions.
#
# ## Data Sources
#
# ### Links:
#
# - NFL dataset: https://github.com/cooperdff/nfl_data_py/tree/main/data
# - Betting data + weather data: https://www.kaggle.com/datasets/tobycrabtree/nfl-scores-and-betting-data/data
# - Robbery data: https://ucr.fbi.gov/crime-in-the-u.s/2016/crime-in-the-u.s.-2016/tables/table-13
# - Aggravated Assaults data: https://ucr.fbi.gov/crime-in-the-u.s/2016/crime-in-the-u.s.-2016/tables/table-14
# - Quarterback Statistics data: https://fftoday.com/stats/
#
# ### How do the datasets complement each other?
#
# - **NFL Statistics Dataset**: This dataset includes game-by-game statistics such as scores, team performances, win/loss records, and player stats. It provides the foundational data for understanding the outcomes of games and the performance metrics of teams and individual players.
#
# - **Weather Dataset**: Contains detailed information about weather conditions for each game, including temperature, wind speed, humidity, and specific weather events (rain, snow, etc.). Weather conditions can significantly affect game strategies and player performance, especially in outdoor stadiums, making this dataset crucial for analyzing game outcomes in relation to environmental factors.
#
# - **Betting Odds Dataset**: Offers insights into how games are perceived by the public and the betting markets before they happen, including the favored team and predicted point spreads and over/under lines. This dataset helps gauge public expectations and market sentiment, which can be compared against actual game outcomes and weather conditions to identify patterns or biases.
#
# - **Quarterback Performance Dataset**: Focuses on the performance metrics of starting quarterbacks, such as touchdowns, completions, and passing yards. Quarterbacks play a pivotal role in their teams' offensive strategies, making their performance data essential for analyzing its impact on game outcomes, especially when cross-referenced with weather conditions and betting odds.
#
# - **Crime Data Dataset**: There are 2 datasets, one on Robbery and one on Aggravated Assault. These datasets offer a unique perspective on the socio-economic environment surrounding the teams, potentially correlating with team performance, fan engagement, and even betting odds. It allows for the exploration of how external societal factors might influence or reflect the dynamics of NFL games.
#
# ### Data Description
#
# #### Size of datasets:
# - NFL DATA (Schedule.csv): (267, 18)
# - BETTING + WEATHER (Betting_weather.csv): (13801,15)
# - ROBBERY (table_13.csv): (54,10)
# - ASSAULTS (table_14.csv): (54,8)
# - QB STATS( nfl_qb_stats.csv): (71,13)
# - Merged_data size: (222, 45)
#
# #### Missing values:
# - Weather_detail: It had 147 missing values after merging. After research, we discovered that these were standard (Sunny/Cloudy) days, and labeled them as such.
# - Quarterback data: Los Angeles has multiple teams, and 2 of them were labeled as LAR in our dataset (LA Rams and LA Raiders), causing some missing values. We fixed this by researching and merging correctly.
# - Stadium: some of the stadiums were not in the USA. These games were dropped.
#
# #### Variables:
#
# - `schedule_date`: The date the game was played.
# - `schedule_playoff`: Indicator of whether the game was part of the playoffs.
# - `team_home`: The home team for the game.
# - `team_away`: The visiting team.
# - `team_favorite_id`: The team favored to win, based on betting odds.
# - `spread_favorite`: The point spread for the favored team.
# - `over_under_line`: The predicted total points for the game by bettors.
# - `stadium`: The stadium where the game was played.
# - `weather_temperature`: Game day temperature.
# - `weather_wind_mph`: Wind speed in miles per hour during the game.
# - `weather_detail`: Specific weather conditions, e.g., rain, snow.
# - `state`: The state where the game was played.
# - `game_id`: A unique identifier for the game.
# - `game_type`: Type of game, e.g., regular season, playoff.
# - `gametime`: The time the game started.
# - `away_score`: Final score for the away team.
# - `home_score`: Final score for the home team.
# - `home_result`: Outcome for the home team (win/loss).
# - `roof`: Type of stadium roof, e.g., open, closed.
# - `surface`: Type of playing surface, e.g., grass, turf.
# - `old_game_id`: Possibly an alternate or previous game identifier.
# - `home_win`: Indicator of a home team win.
# - `away_win`: Indicator of an away team win.
# - `tie`: Indicator of a game tie.
# - `Total Aggravated Assaults`: Number of reported aggravated assaults.
# - `Population`: Population of the area.
# - `Total Robberies`: Total number of robberies.
# - `home_qb`: The starting quarterback for the home team.
# - `away_qb`: The starting quarterback for the away team.
# - `matches_qb`: The total matches the quarterback played for the home team.
# - `matches_qb`: The total matches the quarterback played for the away team.
# - `TD_QB_home`: Touchdowns scored by the home team's quarterback.
# - `TD_QB_away`: Touchdowns scored by the away team's quarterback.
# - `Comp_QB_home`: Pass completions by the home team's quarterback.
# - `Comp_QB_away`: Pass completions by the away team's quarterback.
# - `Yards_QB_home`: Passing yards by the home team's quarterback.
# - `Yards_QB_away`: Passing yards by the away team's quarterback.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
schedule = pd.read_csv('schedule.csv')
betting_weather_df = pd.read_csv('betting_weather.csv')
crime_data = pd.read_csv('table-14.csv')
robbery_data = pd.read_csv('table-13.csv')
nfl_qb_stats = pd.read_csv('nfl qb stats.csv')

# %% [markdown]
# Loading the data using pandas read csv.
#
# There are total of 5 datasets:
#
#
# *   NFL Schedule
# *    NFL Betting Odds + Weather Data
# *    Crime Data
# *   Robbery Data
# *   NFL Quarterback player states

# %%
schedule.sample(5)
# Out:
#      Unnamed: 0          game_id  season game_type  week     gameday  \
# 12           12  2016_01_DET_IND    2016       REG     1   9/11/2016
# 73           73   2016_05_BUF_LA    2016       REG     5   10/9/2016
# 186         186  2016_13_BUF_OAK    2016       REG    13   12/4/2016
# 85           85  2016_06_CLE_TEN    2016       REG     6  10/16/2016
# 120         120   2016_09_ATL_TB    2016       REG     9   11/3/2016
#
#       weekday gametime away_team home_team  away_score  home_score  \
# 12     Sunday    16:25       DET       IND          39          35
# 73     Sunday    16:25       BUF        LA          30          19
# 186    Sunday    16:05       BUF       OAK          24          38
# 85     Sunday    13:00       CLE       TEN          26          28
# 120  Thursday    20:25       ATL        TB          43          28
#
#      home_result                          stadium location      roof  \
# 12            -4                Lucas Oil Stadium     Home      open
# ...

# %%
schedule.describe()
# Out:
#        Unnamed: 0  season        week  away_score  home_score  home_result  \
# count  267.000000   267.0  267.000000  267.000000  267.000000   267.000000
# mean   133.000000  2016.0    9.453184   21.374532   24.363296     2.988764
# std     77.220464     0.0    5.304334    9.312161    9.245556    12.941593
# min      0.000000  2016.0    1.000000    0.000000    0.000000   -38.000000
# 25%     66.500000  2016.0    5.000000   14.500000   17.000000    -5.000000
# 50%    133.000000  2016.0   10.000000   21.000000   24.000000     3.000000
# 75%    199.500000  2016.0   14.000000   27.000000   30.500000    10.000000
# max    266.000000  2016.0   21.000000   48.000000   49.000000    38.000000
#
#         old_game_id
# count  2.670000e+02
# mean   2.016199e+09
# std    2.731753e+05
# min    2.016091e+09
# 25%    2.016101e+09
# 50%    2.016111e+09
# 75%    2.016121e+09
# max    2.017020e+09

# %%
schedule.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   267 non-null    int64
#  1   game_id      267 non-null    object
#  2   season       267 non-null    int64
#  3   game_type    267 non-null    object
#  4   week         267 non-null    int64
#  5   gameday      267 non-null    object
#  6   weekday      267 non-null    object
#  7   gametime     267 non-null    object
#  8   away_team    267 non-null    object
#  9   home_team    267 non-null    object
#  10  away_score   267 non-null    int64
#  11  home_score   267 non-null    int64
#  12  home_result  267 non-null    int64
#  13  stadium      267 non-null    object
#  14  location     267 non-null    object
#  15  roof         267 non-null    object
#  16  surface      267 non-null    object
#  17  old_game_id  267 non-null    int64
# dtypes: int64(7), object(11)
# ...

# %%
betting_weather_df.sample(5)
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 11158    10/12/2014             2014             6             False
# 8686      9/11/2005             2005             1             False
# 13270     9/25/2022             2022             3             False
# 7101      9/12/1999             1999             1             False
# 9230      9/16/2007             2007             2             False
#
#                   team_home             team_away team_favorite_id  \
# 11158        Miami Dolphins     Green Bay Packers               GB
# 8686    San Francisco 49ers        St. Louis Rams              LAR
# 13270  Los Angeles Chargers  Jacksonville Jaguars              LAC
# 7101     New Orleans Saints     Carolina Panthers               NO
# 9230   Jacksonville Jaguars       Atlanta Falcons              JAX
#
#        spread_favorite over_under_line              stadium  stadium_neutral  \
# ...

# %%
betting_weather_df.describe()
# Out:
#        schedule_season  spread_favorite  weather_temperature  \
# count     13801.000000     11322.000000         12423.000000
# mean       1996.638794        -5.372946            58.932222
# std          16.428890         3.438739            15.535721
# min        1966.000000       -26.500000            -6.000000
# 25%        1983.000000        -7.000000            48.000000
# 50%        1998.000000        -4.500000            62.000000
# 75%        2011.000000        -3.000000            72.000000
# max        2023.000000         0.000000            97.000000
#
#        weather_wind_mph  weather_humidity
# count      12407.000000       8476.000000
# mean           7.624647         67.212246
# std            5.713715         15.795938
# min            0.000000          4.000000
# 25%            2.000000         57.000000
# 50%            8.000000         69.000000
# 75%           11.000000         79.000000
# max           40.000000        100.000000

# %%
betting_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13801 entries, 0 to 13800
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   schedule_date        13801 non-null  object
#  1   schedule_season      13801 non-null  int64
#  2   schedule_week        13801 non-null  object
#  3   schedule_playoff     13801 non-null  bool
#  4   team_home            13801 non-null  object
#  5   team_away            13801 non-null  object
#  6   team_favorite_id     11322 non-null  object
#  7   spread_favorite      11322 non-null  float64
#  8   over_under_line      11312 non-null  object
#  9   stadium              13801 non-null  object
#  10  stadium_neutral      13801 non-null  bool
#  11  weather_temperature  12423 non-null  float64
#  12  weather_wind_mph     12407 non-null  float64
#  13  weather_humidity     8476 non-null   float64
#  14  weather_detail       3025 non-null   object
# ...

# %%
crime_data.sample(5)
# Out:
#                                              Table 14 Unnamed: 1 Unnamed: 2  \
# 25                                        Mississippi      2,469        902
# 7                                         Connecticut      4,558        746
# 52  1 The number of aggravated assaults from agenc...        NaN        NaN
# 8                                            Delaware      3,120      1,054
# 1                                             Alabama     17,364      3,994
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 25        340        593        634         71  15,65,661
# 7       1,053      1,579      1,180        103  35,00,401
# 52        NaN        NaN        NaN        NaN        NaN
# 8         596      1,095        375         56   9,50,787
# 1       1,762     10,068      1,540        264  43,92,449

# %%
crime_data.describe()
# Out:
#        Table 14                      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# count        54                              52         52         52
# unique       54                              52         52         51
# top       State  Total \naggravated \nassaults1   Firearms        399
# freq          1                               1          1          2
#
#              Unnamed: 4          Unnamed: 5 Unnamed: 6  Unnamed: 7
# count                52                  52         52          52
# unique               52                  52         47          52
# top     Other \nweapons  Personal \nweapons        106  Population
# freq                  1                   1          2           1

# %%
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Table 14    54 non-null     object
#  1   Unnamed: 1  52 non-null     object
#  2   Unnamed: 2  52 non-null     object
#  3   Unnamed: 3  52 non-null     object
#  4   Unnamed: 4  52 non-null     object
#  5   Unnamed: 5  52 non-null     object
#  6   Unnamed: 6  52 non-null     object
#  7   Unnamed: 7  52 non-null     object
# dtypes: object(8)
# memory usage: 3.5+ KB

# %%
robbery_data.sample(5)
# Out:
#         Table 13 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 39  Pennsylvania     11,764      5,077        786        780      5,121
# 1        Alabama      4,415      2,876        143        369      1,027
# 13         Idaho        209         56         36         32         85
# 24     Minnesota      3,725      1,193        288        588      1,656
# 18      Kentucky      3,369      1,664        238        330      1,137
#
#    Unnamed: 6   Unnamed: 7 Unnamed: 8 Unnamed: 9
# 39      1,241  1,16,91,589        NaN        NaN
# 1         264    43,92,449        NaN        NaN
# 13        108    16,80,830        NaN        NaN
# 24        377    55,19,952        NaN        NaN
# 18        420    44,24,357        NaN        NaN

# %%
robbery_data.describe()
# Out:
#        Table 13 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# count        54         52         52         52         52         52
# unique       54         51         51         51         49         51
# top       State        266      1,357        238        579         22
# freq          1          2          2          2          2          2
#
#        Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9
# count          52          52          1          2
# unique         47          52          1          1
# top           106  Population
# freq            2           1          1          2

# %%
robbery_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Table 13    54 non-null     object
#  1   Unnamed: 1  52 non-null     object
#  2   Unnamed: 2  52 non-null     object
#  3   Unnamed: 3  52 non-null     object
#  4   Unnamed: 4  52 non-null     object
#  5   Unnamed: 5  52 non-null     object
#  6   Unnamed: 6  52 non-null     object
#  7   Unnamed: 7  52 non-null     object
#  8   Unnamed: 8  1 non-null      object
#  9   Unnamed: 9  2 non-null      object
# dtypes: object(10)
# memory usage: 4.3+ KB

# %%
nfl_qb_stats.sample(5)
# Out:
#                  Player Team   G  Comp  Att   Yard  TD  INT  Att.1  Yard.1  \
# 29      30. Case Keenum   LA  10   196  322  2,201   9   11     20      51
# 57      58. David Fales  CHI   1     2    5     22   0    0      1       0
# 61         62. Joe Webb  CAR   1     0    0      0   0    0      0       0
# 66     67. Ryan Mallett  BAL   4     3    6     26   0    1      5      -6
# 31   32. Blaine Gabbert   SF   6    91  160    925   5    6     40     173
#
#     TD.1   FPts  FPts/G
# 29     1  157.2    15.7
# 57     0    1.1     1.1
# 61     0    0.0     0.0
# 66     0    0.7     0.2
# 31     2   95.6    15.9

# %%
nfl_qb_stats.describe()
# Out:
#                G        Comp         Att         TD        INT      Att.1  \
# count  71.000000   71.000000   71.000000  71.000000  71.000000  71.000000
# mean    9.859155  198.704225  315.859155  13.309859   7.126761  25.887324
# std     5.545386  151.007890  232.920728  11.658953   5.719464  25.585459
# min     1.000000    0.000000    0.000000   0.000000   0.000000   0.000000
# 25%     5.000000   47.500000   78.000000   2.500000   2.000000   6.500000
# 50%    10.000000  196.000000  322.000000   9.000000   6.000000  16.000000
# 75%    15.000000  351.000000  545.500000  22.000000  12.500000  38.500000
# max    16.000000  471.000000  673.000000  40.000000  21.000000  95.000000
#
#            Yard.1       TD.1        FPts     FPts/G
# count   71.000000  71.000000   71.000000  71.000000
# mean   105.563380   1.169014  184.212676  15.446479
# std    142.380851   1.740164  143.482367   7.203071
# min     -9.000000   0.000000    0.000000   0.000000
# ...

# %%
nfl_qb_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  71 non-null     object
#  1   Team    71 non-null     object
#  2   G       71 non-null     int64
#  3   Comp    71 non-null     int64
#  4   Att     71 non-null     int64
#  5   Yard    71 non-null     object
#  6   TD      71 non-null     int64
#  7   INT     71 non-null     int64
#  8   Att.1   71 non-null     int64
#  9   Yard.1  71 non-null     int64
#  10  TD.1    71 non-null     int64
#  11  FPts    71 non-null     float64
#  12  FPts/G  71 non-null     float64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 7.3+ KB

# %% [markdown]
# Above is giving an overview of the datasets we are using. There are descriptions of the attributes and datatype contained.

# %% [markdown]
# ## Preprocessing Betting Weather data

# %%
team_mapping = {
    'Arizona Cardinals': 'ARI',
    'Atlanta Falcons': 'ATL',
    'Baltimore Colts': 'BAL',
    'Baltimore Ravens': 'BAL',
    'Boston Patriots': 'NE',
    'Buffalo Bills': 'BUF',
    'Carolina Panthers': 'CAR',
    'Chicago Bears': 'CHI',
    'Cincinnati Bengals': 'CIN',
    'Cleveland Browns': 'CLE',
    'Dallas Cowboys': 'DAL',
    'Denver Broncos': 'DEN',
    'Detroit Lions': 'DET',
    'Green Bay Packers': 'GB',
    'Houston Oilers': 'HOU',
    'Houston Texans': 'HOU',
    'Indianapolis Colts': 'IND',
    'Jacksonville Jaguars': 'JAC',
    'Kansas City Chiefs': 'KC',
    'Las Vegas Raiders': 'LV',
    'Los Angeles Chargers': 'LAC',
    'Los Angeles Raiders': 'LAR',
    'Los Angeles Rams': 'LA',
    'Miami Dolphins': 'MIA',
    'Minnesota Vikings': 'MIN',
    'New England Patriots': 'NE',
    'New Orleans Saints': 'NO',
    'New York Giants': 'NYG',
    'New York Jets': 'NYJ',
    'Oakland Raiders': 'LV',
    'Philadelphia Eagles': 'PHI',
    'Phoenix Cardinals': 'ARI',
    'Pittsburgh Steelers': 'PIT',
    'San Diego Chargers': 'LAC',
    'San Francisco 49ers': 'SF',
    'Seattle Seahawks': 'SEA',
    'St. Louis Cardinals': 'ARI',
    'St. Louis Rams': 'LA',
    'Tampa Bay Buccaneers': 'TB',
    'Tennessee Oilers': 'TEN',
    'Tennessee Titans': 'TEN',
    'Washington Commanders': 'WAS',
    'Washington Football Team': 'WAS',
    'Washington Redskins': 'WAS'
}

# %%
betting_weather_df['team_away'] = betting_weather_df['team_away'].map(team_mapping)
betting_weather_df['team_home'] = betting_weather_df['team_home'].map(team_mapping)
betting_weather_df.sample(5)
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 12860     12/6/2020             2020            13             False
# 6354       9/1/1996             1996             1             False
# 6348       9/1/1996             1996             1             False
# 1883      9/19/1976             1976             2             False
# 2968       9/6/1981             1981             1             False
#
#       team_home team_away team_favorite_id  spread_favorite over_under_line  \
# 12860        KC       DEN               KC            -13.0            51.5
# 6354         TB        GB               GB             -6.0            39.5
# 6348        MIA        NE              MIA             -3.0            43.5
# 1883        PHI       NYG              NaN              NaN             NaN
# 2968        ATL        NO              ATL            -10.0              45
#
#                              stadium  stadium_neutral  weather_temperature  \
# ...

# %%
team_to_state = {
    'ARI': 'Arizona', 'ATL': 'Georgia', 'BAL': 'Maryland', 'BUF': 'New York', 'CAR': 'North Carolina',
    'CHI': 'Illinois', 'CIN': 'Ohio', 'CLE': 'Ohio', 'DAL': 'Texas', 'DEN': 'Colorado', 'DET': 'Michigan',
    'GB': 'Wisconsin', 'HOU': 'Texas', 'IND': 'Indiana', 'JAC': 'Florida', 'KC': 'Missouri', 'LA': 'California',
    'LAC': 'California', 'LV': 'Nevada', 'MIA': 'Florida', 'MIN': 'Minnesota', 'NE': 'Massachusetts',
    'NO': 'Louisiana', 'NYG': 'New York', 'NYJ': 'New York', 'PHI': 'Pennsylvania', 'PIT': 'Pennsylvania',
    'SEA': 'Washington', 'SF': 'California', 'TB': 'Florida', 'TEN': 'Tennessee', 'WAS': 'Maryland'
}

# %%
betting_weather_df['state'] = betting_weather_df['team_home'].map(team_to_state)

# %% [markdown]
# Above is a mapping that will be used to merged multiple datasets. Here we are mapping team names and states to a unique 3 letter code. We are applying that mapping to the datasets to create a linking variable

# %% [markdown]
# ## Preprocessing Schedule data

# %%
schedule['home_win'] = schedule['home_score'] > schedule['away_score']
schedule['away_win'] = schedule['home_score'] < schedule['away_score']
schedule['tie'] = schedule['home_score'] == schedule['away_score']

# %% [markdown]
# creating win and away columns in the schedule dataset

# %% [markdown]
# ## Preprocessing crime data

# %%
# Cleaning and renaming columns in crime data for clarity
crime_data.columns = [
    'State', 'Total Aggravated Assaults', 'Firearms', 'Knives or Cutting Instruments',
    'Other Weapons', 'Personal Weapons', 'Agency Count', 'Population'
]
crime_data = crime_data.loc[1:]  # Remove the header row
crime_data['State'] = crime_data['State'].str.strip()   # Clean and prepare 'State' column in crime data
crime_data = crime_data.dropna(subset=['Total Aggravated Assaults'])    # Remove rows with missing or irrelevant data based on 'Total Aggravated Assaults'

# %%
crime_data['State'] = crime_data['State'].replace('Illinois2', 'Illinois')

# %%
crime_data
# Out:
#                    State Total Aggravated Assaults Firearms  \
# 1                Alabama                    17,364    3,994
# 2                 Alaska                     3,992      883
# 3                Arizona                    19,232    5,024
# 4               Arkansas                    11,385    3,884
# 5             California                  1,04,295   20,633
# 6               Colorado                    11,271    3,590
# 7            Connecticut                     4,558      746
# 8               Delaware                     3,120    1,054
# 9   District of Columbia                     4,063    1,057
# 10               Florida                    59,678   17,506
# 11               Georgia                    22,896    8,329
# 12                Hawaii                     2,769      180
# 13                 Idaho                     2,866      613
# 14              Illinois                     1,745      955
# 15               Indiana                    14,225    3,233
# ...

# %%
for column in crime_data.columns:
    if column != 'State':
        crime_data[column] = crime_data[column].str.replace(',', '').astype(int)

# %%
crime_data['State'] = crime_data['State'].astype(str)

# %% [markdown]
# Cleaning up the crime data to only include attributes relevant to our analysis. Also making sure there are no repeat columns like Illinois and Illinois2

# %% [markdown]
# ## Preprocess Robbery Data

# %%
robbery_data = robbery_data.drop([52, 53])
robbery_data.columns = robbery_data.iloc[0]# Set the first row as column names
robbery_data = robbery_data[1:]
robbery_data = robbery_data.reset_index(drop=True)# Reset index

# %%
robbery_data['State'] = robbery_data['State'].str.strip()

# %%
robbery_data_reduced = robbery_data[['State', 'Total\nrobberies1']]

# %%
robbery_data_reduced['State'] = robbery_data_reduced['State'].replace('Illinois2', 'Illinois')
# Out:
# /var/folders/5s/fpydwv6n7kzb46w2tptt4bjr0000gn/T/ipykernel_54801/2486044266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   robbery_data_reduced['State'] = robbery_data_reduced['State'].replace('Illinois2', 'Illinois')

# %%
robbery_data_reduced['Total\nrobberies1'] = robbery_data_reduced['Total\nrobberies1'].str.replace(',', '').astype(int)
# Out:
# /var/folders/5s/fpydwv6n7kzb46w2tptt4bjr0000gn/T/ipykernel_54801/395854134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   robbery_data_reduced['Total\nrobberies1'] = robbery_data_reduced['Total\nrobberies1'].str.replace(',', '').astype(int)

# %%
robbery_data_reduced
# Out:
# 0                  State  Total\nrobberies1
# 0                Alabama               4415
# 1                 Alaska                848
# 2                Arizona               6882
# 3               Arkansas               2045
# 4             California              54762
# 5               Colorado               3432
# 6            Connecticut               2696
# 7               Delaware               1359
# 8   District of Columbia               3480
# 9                Florida              20132
# 10               Georgia              11935
# 11                Hawaii                994
# 12                 Idaho                209
# 13              Illinois                536
# 14               Indiana               6883
# 15                  Iowa               1131
# 16                Kansas               1248
# 17              Kentucky               3369
# 18             Louisiana               5514
# 19                 Maine                266
# ...

# %% [markdown]
# Cleaned and structured a robbery dataset by performing several preprocessing steps and removed two specific rows that might have contained errors(as per the FBI Website). Designated the first row as the column headers for clarity and removed it afterward to avoid redundancy. Reset the dataset's index for consistency, trimmed any extra spaces from the 'State' column values to ensure data uniformity, and created a simplified version of the dataset focusing on key columns. Additionally,Corrected a mislabeled state name and converted the robbery counts to integers after removing commas, making the data ready for numerical analysis. These steps were all aimed at preparing the dataset for more efficient and accurate data analysis.

# %% [markdown]
# ## Preprocess NFL_QB_STATS

# %%
nfl_qb_stats['G'] = pd.to_numeric(nfl_qb_stats['G'])
nfl_qb_stats_sorted = nfl_qb_stats.sort_values(['Team', 'G'], ascending=[True, False])
nfl_qb_stats_cleaned = nfl_qb_stats_sorted.drop_duplicates(subset=['Team'], keep='first')
nfl_qb_stats_cleaned.reset_index(drop=True, inplace=True)
nfl_qb_stats_cleaned
# Out:
#                      Player Team   G  Comp  Att   Yard  TD  INT  Att.1  \
# 0         14. Carson Palmer  ARI  15   365  598  4,237  26   14     14
# 1              3. Matt Ryan  ATL  16   373  534  4,944  38    7     35
# 2            18. Joe Flacco  BAL  16   437  673  4,317  20   15     22
# 3          19. Tyrod Taylor  BUF  15   270  437  3,023  17    6     95
# 4            15. Cam Newton  CAR  15   270  509  3,509  19   14     90
# 5          31. Matt Barkley  CHI   7   129  216  1,611   8   14      7
# 6           12. Andy Dalton  CIN  16   364  563  4,206  18    8     46
# 7          34. Cody Kessler  CLE   9   128  195  1,380   6    2     11
# 8           9. Dak Prescott  DAL  16   311  459  3,667  23    4     57
# 9        26. Trevor Siemian  DEN  14   289  486  3,401  18   10     28
# 10      7. Matthew Stafford  DET  16   388  594  4,327  24   10     37
# 11         1. Aaron Rodgers   GB  16   401  610  4,428  40    7     67
# ...

# %% [markdown]
# Processed the NFL quarterback dataset, focusing on highlighting the most active quarterback for each team. Initially, the 'G' column, which is number of games played, is converted to a numeric data type to facilitate sorting. The dataset is then sorted by team in ascending order and by games played in descending order, ensuring quarterbacks are organized within their teams based on the number of games played. Following the sorting, duplicates are removed, keeping only the entry with the highest number of games played for each team, effectively selecting the most active or starting quarterback.

# %% [markdown]
# ## Data Merging

# %%
merged_df = pd.merge(betting_weather_df, schedule, left_on=['schedule_date', 'team_away', 'team_home'], right_on=['gameday', 'away_team', 'home_team'], how='inner')

# %%
merged_df.drop(columns= ['Unnamed: 0', 'season', 'away_team', 'home_team'], inplace=True)

# %%
merged_df['favorite_win'] = (merged_df['team_favorite_id'] == merged_df['team_home']) & (merged_df['home_win']) | (merged_df['team_favorite_id'] == merged_df['team_away']) & (merged_df['away_win'])
merged_df['upset_win'] = (merged_df['team_favorite_id'] == merged_df['team_home']) & (merged_df['away_win']) | (merged_df['team_favorite_id'] == merged_df['team_away']) & (merged_df['home_win'])

# %%
merged_data = pd.merge(merged_df, crime_data, how='left', left_on='state', right_on='State')

# %%
print(merged_data[['team_home', 'state', 'Total Aggravated Assaults', 'Firearms', 'Knives or Cutting Instruments', 'Other Weapons', 'Personal Weapons', 'Agency Count', 'Population']].head())
# Out:
#   team_home     state  Total Aggravated Assaults  Firearms  \
# 0       DEN  Colorado                      11271      3590
# 1       ARI   Arizona                      19232      5024
# 2       ATL   Georgia                      22896      8329
# 3       BAL  Maryland                      14595      2474
# 4       DAL     Texas                      71583     21222
#
#    Knives or Cutting Instruments  Other Weapons  Personal Weapons  \
# 0                           2651           2778              2252
# 1                           2822           4559              6827
# 2                           3204           5867              5496
# 3                           3420           5387              3314
# 4                          14482          22677             13202
#
#    Agency Count  Population
# 0           197     5109023
# 1            90     6514042
# 2           504     9639636
# 3           148     5312551
# 4           984    27340228

# %%
merged_data = pd.merge(merged_data, robbery_data_reduced, how='left', left_on='state', right_on='State')
merged_data
# Out:
#     schedule_date  schedule_season schedule_week  schedule_playoff team_home  \
# 0        9/8/2016             2016             1             False       DEN
# 1       9/11/2016             2016             1             False       ARI
# 2       9/11/2016             2016             1             False       ATL
# 3       9/11/2016             2016             1             False       BAL
# 4       9/11/2016             2016             1             False       DAL
# ..            ...              ...           ...               ...       ...
# 217     1/15/2017             2016      Division              True       DAL
# 218     1/15/2017             2016      Division              True        KC
# 219     1/22/2017             2016    Conference              True       ATL
# 220     1/22/2017             2016    Conference              True        NE
# 221      2/5/2017             2016     Superbowl              True       ATL
#
# ...

# %%
merged_data.columns
# Out:
# Index(['schedule_date', 'schedule_season', 'schedule_week', 'schedule_playoff',
#        'team_home', 'team_away', 'team_favorite_id', 'spread_favorite',
#        'over_under_line', 'stadium_x', 'stadium_neutral',
#        'weather_temperature', 'weather_wind_mph', 'weather_humidity',
#        'weather_detail', 'state', 'game_id', 'game_type', 'week', 'gameday',
#        'weekday', 'gametime', 'away_score', 'home_score', 'home_result',
#        'stadium_y', 'location', 'roof', 'surface', 'old_game_id', 'home_win',
#        'away_win', 'tie', 'favorite_win', 'upset_win', 'State_x',
#        'Total Aggravated Assaults', 'Firearms',
#        'Knives or Cutting Instruments', 'Other Weapons', 'Personal Weapons',
#        'Agency Count', 'Population', 'State_y', 'Total\nrobberies1'],
#       dtype='object')

# %%
team_to_qb_dict = nfl_qb_stats_cleaned.set_index('Team')['Player'].to_dict()
team_to_qb_dict
# Out:
# {'ARI': '\xa014.\xa0Carson Palmer',
#  'ATL': '\xa03.\xa0Matt Ryan',
#  'BAL': '\xa018.\xa0Joe Flacco',
#  'BUF': '\xa019.\xa0Tyrod Taylor',
#  'CAR': '\xa015.\xa0Cam Newton',
#  'CHI': '\xa031.\xa0Matt Barkley',
#  'CIN': '\xa012.\xa0Andy Dalton',
#  'CLE': '\xa034.\xa0Cody Kessler',
#  'DAL': '\xa09.\xa0Dak Prescott',
#  'DEN': '\xa026.\xa0Trevor Siemian',
#  'DET': '\xa07.\xa0Matthew Stafford',
#  'GB': '\xa01.\xa0Aaron Rodgers',
#  'HOU': '\xa028.\xa0Brock Osweiler',
#  'IND': '\xa04.\xa0Andrew Luck',
#  'JAC': '\xa08.\xa0Blake Bortles',
#  'KC': '\xa024.\xa0Alex Smith',
#  'LA': '\xa030.\xa0Case Keenum',
#  'LAR': '\xa036.\xa0Jared Goff',
#  'LV': '\xa016.\xa0Derek Carr',
#  'MIA': '\xa025.\xa0Ryan Tannehill',
#  'MIN': '\xa023.\xa0Sam Bradford',
#  'NE': '\xa021.\xa0Tom Brady',
#  'NO': '\xa02.\xa0Drew Brees',
#  'NYG': '\xa020.\xa0Eli Manning',
#  'NYJ': '\xa029.\xa0Ryan Fitzpatrick',
#  'PHI': '\xa022.\xa0Carson Wentz',
#  'PIT': '\xa017.\xa0Ben Roethlisberger',
# ...

# %%
# Map the QB names to the home and away teams in the nfl_betting_weather_crime dataset
merged_data['home_qb'] = merged_data['team_home'].map(team_to_qb_dict)
merged_data['away_qb'] = merged_data['team_away'].map(team_to_qb_dict)

# Check the first few rows to ensure the merge worked as expected
merged_data[['team_home', 'home_qb', 'team_away', 'away_qb']].head()
# Out:
#   team_home              home_qb team_away              away_qb
# 0       DEN   26. Trevor Siemian       CAR       15. Cam Newton
# 1       ARI    14. Carson Palmer        NE        21. Tom Brady
# 2       ATL         3. Matt Ryan        TB   10. Jameis Winston
# 3       BAL       18. Joe Flacco       BUF     19. Tyrod Taylor
# 4       DAL      9. Dak Prescott       NYG      20. Eli Manning

# %%
# Create mappings for the requested QB stats
# We will sum passing TDs and rushing TDs for the total TDs per QB
nfl_qb_stats_cleaned['Total_TD'] = nfl_qb_stats_cleaned['TD'] + nfl_qb_stats_cleaned['TD.1']

# Mapping dictionaries for the stats
team_to_td_dict = nfl_qb_stats_cleaned.set_index('Team')['Total_TD'].to_dict()
team_to_comp_dict = nfl_qb_stats_cleaned.set_index('Team')['Comp'].to_dict()
team_to_yards_dict = nfl_qb_stats_cleaned.set_index('Team')['Yard'].to_dict()
team_to_games_dict = nfl_qb_stats_cleaned.set_index('Team')['G'].to_dict()

# Convert 'Yard' strings to numeric values (removing commas)
nfl_qb_stats_cleaned['Yard'] = nfl_qb_stats_cleaned['Yard'].str.replace(',', '').astype(int)
team_to_yards_dict = nfl_qb_stats_cleaned.set_index('Team')['Yard'].to_dict()

# Map the QB stats to the home and away teams in the nfl_betting_weather_crime dataset
merged_data['TD_QB_home'] = merged_data['team_home'].map(team_to_td_dict)
merged_data['TD_QB_away'] = merged_data['team_away'].map(team_to_td_dict)
merged_data['Comp_QB_home'] = merged_data['team_home'].map(team_to_comp_dict)
merged_data['Comp_QB_away'] = merged_data['team_away'].map(team_to_comp_dict)
merged_data['Yards_QB_home'] = merged_data['team_home'].map(team_to_yards_dict)
merged_data['Yards_QB_away'] = merged_data['team_away'].map(team_to_yards_dict)
merged_data['Games_QB_home'] = merged_data['team_home'].map(team_to_games_dict)
merged_data['Games_QB_away'] = merged_data['team_away'].map(team_to_games_dict)

# Check the first few rows to ensure the stats were mapped correctly
merged_data[['team_home', 'TD_QB_home', 'Comp_QB_home', 'Yards_QB_home', 'team_away', 'TD_QB_away', 'Comp_QB_away', 'Yards_QB_away','Games_QB_home','Games_QB_away']].head()
# Out:
# /var/folders/5s/fpydwv6n7kzb46w2tptt4bjr0000gn/T/ipykernel_54801/3160119575.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nfl_qb_stats_cleaned['Total_TD'] = nfl_qb_stats_cleaned['TD'] + nfl_qb_stats_cleaned['TD.1']
# /var/folders/5s/fpydwv6n7kzb46w2tptt4bjr0000gn/T/ipykernel_54801/3160119575.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nfl_qb_stats_cleaned['Yard'] = nfl_qb_stats_cleaned['Yard'].str.replace(',', '').astype(int)
# ...

# %%
merged_data.columns
# Out:
# Index(['schedule_date', 'schedule_season', 'schedule_week', 'schedule_playoff',
#        'team_home', 'team_away', 'team_favorite_id', 'spread_favorite',
#        'over_under_line', 'stadium_x', 'stadium_neutral',
#        'weather_temperature', 'weather_wind_mph', 'weather_humidity',
#        'weather_detail', 'state', 'game_id', 'game_type', 'week', 'gameday',
#        'weekday', 'gametime', 'away_score', 'home_score', 'home_result',
#        'stadium_y', 'location', 'roof', 'surface', 'old_game_id', 'home_win',
#        'away_win', 'tie', 'favorite_win', 'upset_win', 'State_x',
#        'Total Aggravated Assaults', 'Firearms',
#        'Knives or Cutting Instruments', 'Other Weapons', 'Personal Weapons',
#        'Agency Count', 'Population', 'State_y', 'Total\nrobberies1', 'home_qb',
#        'away_qb', 'TD_QB_home', 'TD_QB_away', 'Comp_QB_home', 'Comp_QB_away',
#        'Yards_QB_home', 'Yards_QB_away', 'Games_QB_home', 'Games_QB_away'],
#       dtype='object')

# %%
# Drop unnecessary columns
merged_data.drop(['State_y', 'stadium_y', 'stadium_x', 'location', 'Firearms', 'Knives or Cutting Instruments', 'Other Weapons', 'Personal Weapons', 'Agency Count','weather_humidity'], axis=1,inplace = True)

# %%
merged_data.isna().sum()
# Out:
# schedule_date                  0
# schedule_season                0
# schedule_week                  0
# schedule_playoff               0
# team_home                      0
# team_away                      0
# team_favorite_id               0
# spread_favorite                0
# over_under_line                0
# stadium_neutral                0
# weather_temperature            0
# weather_wind_mph               0
# weather_detail               147
# state                          0
# game_id                        0
# game_type                      0
# week                           0
# gameday                        0
# weekday                        0
# gametime                       0
# away_score                     0
# home_score                     0
# home_result                    0
# roof                           0
# surface                        0
# old_game_id                    0
# home_win                       0
# away_win                       0
# ...

# %%
merged_data[merged_data['weather_detail'].isna()]
# Out:
#     schedule_date  schedule_season schedule_week  schedule_playoff team_home  \
# 0        9/8/2016             2016             1             False       DEN
# 3       9/11/2016             2016             1             False       BAL
# 7       9/11/2016             2016             1             False       NYJ
# 8       9/11/2016             2016             1             False       PHI
# 9       9/11/2016             2016             1             False       SEA
# ..            ...              ...           ...               ...       ...
# 213      1/8/2017             2016      Wildcard              True        GB
# 214      1/8/2017             2016      Wildcard              True       PIT
# 216     1/14/2017             2016      Division              True        NE
# 218     1/15/2017             2016      Division              True        KC
# 220     1/22/2017             2016    Conference              True        NE
#
# ...

# %%
merged_data.weather_detail.fillna('Standard',inplace = True)

# %%
merged_data.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff team_home  \
# 0      9/8/2016             2016             1             False       DEN
# 1     9/11/2016             2016             1             False       ARI
# 2     9/11/2016             2016             1             False       ATL
# 3     9/11/2016             2016             1             False       BAL
# 4     9/11/2016             2016             1             False       DAL
#
#   team_away team_favorite_id  spread_favorite over_under_line  \
# 0       CAR              CAR             -3.0            40.5
# 1        NE              ARI             -8.5              44
# 2        TB              ATL             -2.5              47
# 3       BUF              BAL             -3.0            44.5
# 4       NYG              NYG             -1.0            47.5
#
#    stadium_neutral  ...              away_qb  TD_QB_home TD_QB_away  \
# 0            False  ...       15. Cam Newton          18         24
# ...

# %%
merged_data.describe()
# Out:
#        schedule_season  spread_favorite  weather_temperature  \
# count            222.0       222.000000           222.000000
# mean            2016.0        -4.923423            60.752252
# std                0.0         3.043574            17.454449
# min             2016.0       -17.000000             2.000000
# 25%             2016.0        -6.875000            48.250000
# 50%             2016.0        -4.000000            66.500000
# 75%             2016.0        -3.000000            72.000000
# max             2016.0         0.000000            89.000000
#
#        weather_wind_mph        week  away_score  home_score  home_result  \
# count        222.000000  222.000000  222.000000  222.000000   222.000000
# mean           3.954955    9.468468   20.986486   24.148649     3.162162
# std            3.888462    5.343952    9.626735    9.461064    13.587351
# min            0.000000    1.000000    0.000000    0.000000   -38.000000
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   schedule_date              222 non-null    object
#  1   schedule_season            222 non-null    int64
#  2   schedule_week              222 non-null    object
#  3   schedule_playoff           222 non-null    bool
#  4   team_home                  222 non-null    object
#  5   team_away                  222 non-null    object
#  6   team_favorite_id           222 non-null    object
#  7   spread_favorite            222 non-null    float64
#  8   over_under_line            222 non-null    object
#  9   stadium_neutral            222 non-null    bool
#  10  weather_temperature        222 non-null    float64
#  11  weather_wind_mph           222 non-null    float64
#  12  weather_detail             222 non-null    object
# ...

# %% [markdown]
# We merge NFL game, betting, weather, crime, and quarterback statistics into a single dataset. We start by combining betting and weather data with the NFL schedule based on dates and teams. After refining the dataset by removing unnecessary columns, we add indicators for favorite team wins and upsets. The dataset is then merged with crime data based on state and quarterback statistics by mapping QB names to their respective teams. The final dataset undergoes cleaning, including type conversion and column removal, to ensure it's streamlined for analysis.

# %% [markdown]
# ## Data Visualization

# %%
home_advantage = merged_data['home_win'].mean()
away_win = merged_data['away_win'].mean()
betting_favorite = merged_data['favorite_win'].mean()
betting_upset = merged_data['upset_win'].mean()

# %%
plt.figure(figsize=(10, 6))
plt.bar(['Home Team', 'Away Team', 'Betting Favorite', 'Betting Upset'], [home_advantage, away_win, betting_favorite, betting_upset])
plt.title('Home Advantage vs Betting Line')
plt.ylabel('Win Percentage')
plt.show()

# %% [markdown]
# The above plot is showing the "home-advantage" and betting favorite effect. We can see that the betting favorite is more likely to win than the home team.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(merged_data['spread_favorite'], kde=True)
plt.title('Spread Distribution')
plt.xlabel('Spread')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The above plot is a histogram of the "spread" of the game. The spead is the expected point differential. We see that the plot is left skwere with a center around -5

# %%
g = sns.JointGrid(data=merged_data, x='weather_temperature',y='spread_favorite', height=8)
g = g.plot(sns.regplot, sns.histplot)

# %% [markdown]
# The scatterplot with a fitted regression line indicating a potential relationship between weather temperature and the betting spread for the favorite team in NFL games. As the temperature increases, the favorite team's expected winning margin slightly decreases. The histograms show most games occur at temperatures between 60-80°F and betting spreads are commonly set between -2.5 and -7.5 points. The plot suggests a possible trend where warmer weather is associated with closer games, but further analysis is needed to confirm any statistical significance.

# %%
merged_data['total_score'] = merged_data['home_score'] + merged_data['away_score']
g = sns.JointGrid(data=merged_data, x='weather_temperature',y='total_score', height=8)
g = g.plot(sns.regplot, sns.histplot)

# %% [markdown]
# The regression and dotplot of temperature by total score. We see that there is a weak positive relationship between the variables

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.histplot(merged_data['total_score'], kde=True, color='skyblue', bins=30)
plt.title('Total Score Distribution Across Games')
plt.xlabel('Total Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Above is a histogram of the total score of NFL games, we see that it is normally distributed with a center of around 50

# %%
sns.kdeplot(merged_data['home_score'], label='Home Score', shade=True, color='blue')
sns.kdeplot(merged_data['away_score'], label='Away Score', shade=True, color='red')
plt.title('Home vs Away Score Density')
plt.xlabel('Score')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# /var/folders/5s/fpydwv6n7kzb46w2tptt4bjr0000gn/T/ipykernel_54801/2986254537.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(merged_data['home_score'], label='Home Score', shade=True, color='blue')
# /var/folders/5s/fpydwv6n7kzb46w2tptt4bjr0000gn/T/ipykernel_54801/2986254537.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(merged_data['away_score'], label='Away Score', shade=True, color='red')

# %% [markdown]
# Above is a KDE Plot of the total score of NFL games separated by home and away team, we see that there are both are normally distributed with home team. The home team's distribution has a slightly higher peak than the away team's, indicating a higher density of scores around the mean for home teams.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='team_favorite_id', y='spread_favorite', data=merged_data)
plt.title('Spread Favorite by Team')
plt.xticks(rotation=90)
plt.xlabel('Favorite Team')
plt.ylabel('Spread Favorite')
plt.show()

# %% [markdown]
# Above is a plot of the showing the boxplot or distribution of the spread per team. We can see certain teams are expected to win by a larger margin. Such as NE (new england) and SEA (seattle)

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='TD_QB_home', y='TD_QB_away', hue='schedule_playoff', data=merged_data, style='schedule_playoff', s=100)
plt.title('Touchdowns by Home vs Away Quarterbacks')
plt.xlabel('Touchdowns by Home Quarterbacks')
plt.ylabel('Touchdowns by Away Quarterbacks')
plt.legend(title='Playoff Game')
plt.show()

# %% [markdown]
# The plot shows a wide distribution of touchdowns by both home and away quarterbacks, with no clear pattern of one outperforming the other significantly. There are instances in playoff games where both home and away quarterbacks have high touchdown counts, suggesting competitive performance in high-stakes games.

# %%
# Aggregating home and away wins for each state
home_wins_by_state = merged_data.groupby('state')['home_win'].sum().reset_index()
away_wins_by_state = merged_data.groupby('state')['away_win'].sum().reset_index()

# Combining home and away wins by state
wins_by_state = pd.merge(home_wins_by_state, away_wins_by_state, on='state', how='outer')
wins_by_state['total_wins'] = wins_by_state['home_win'] + wins_by_state['away_win']

avg_crime_by_state = merged_data.groupby('state')[['Total Aggravated Assaults','Population']].mean().reset_index()

# Merging win data with crime data
state_analysis = pd.merge(wins_by_state, avg_crime_by_state, on='state')

# %%
state_analysis['crime_rate']=state_analysis['Total Aggravated Assaults']/state_analysis['Population']

# %%
# Visualizing the relationship between total wins and crime rates by state
plt.figure(figsize=(14, 8))
sns.scatterplot(x='total_wins', y='crime_rate', hue='state', data=state_analysis, palette='Set2', s=150)
plt.title('Total Wins vs Crime Rates by State')
plt.xlabel('Total Wins (Home and Away)')
plt.ylabel('Average Crime Rate')
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# In this plot the x-axis represents the total number of wins, and the y-axis represents the average crime rate. The points are spread across the plot, suggesting variability in both wins and crime rates across different states. Without further statistical analysis, it's not clear if there is a significant correlation between the two variables.

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x='State',y='Total\nrobberies1',data=robbery_data_reduced.sort_values(by='Total\nrobberies1', ascending= False).iloc[:5,:])
plt.title('Robberies by State')
plt.xlabel('State')
plt.ylabel('Robberies')
plt.show()

# %% [markdown]
# We can visualize the robberies data set using a barplot. The state of California has the higest Robberies among all the states, followed by texas.

# %%
figsize = (12,8)
plt.figure(figsize=figsize)
sns.violinplot(merged_data, x='spread_favorite', y='weather_detail', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# /var/folders/5s/fpydwv6n7kzb46w2tptt4bjr0000gn/T/ipykernel_54801/2533895098.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(merged_data, x='spread_favorite', y='weather_detail', inner='stick', palette='Dark2')

# %% [markdown]
# The violin plot visualizes the distribution of betting spreads for the favorite team across different weather conditions. The spread of data within each category shows the probability density of the spreads at different points. A quick glance indicates that the weather conditions might have varying impacts on the betting spreads,We can observe high variablity when it rains but without statistical analysis, we can't draw a definitive conclusion about the nature or significance of these impacts.
